# %%
import nltk
import string
from nltk.stem.wordnet import WordNetLemmatizer
from pyavrophonetic import avro
from guess_language import guess_language
import pandas as pd
from nltk.corpus import words as nltk_words
import re
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
% cd /media/wasifur/LinuxChotoBhai/Uber_users_in_BD
% ls
# Out:
# /media/wasifur/LinuxChotoBhai/Uber_users_in_BD
# 5dc2a4eb901594578e3780a6f33dee02dad1.pdf*  uber_comments.csv*
# status_by_language.txt*                    uber_group_posts.csv*
# Uber_code/                                 uber_sub_comments.csv*

# %%
english_word_file = open("/usr/share/dict/british-english","r")
english_words = set([])
for word in english_word_file.read().splitlines():
    english_words.add(word)

#english_words

#dictionary = dict.fromkeys(nltk_words.words(), None)

# %%
bangla = avro.parse("ami farhin ke valobasi")
bangla
# Out:
# 'আমি ফারহিন কে ভালবাসি'

# %%
for char in bangla:
    print(char, ord(char))
    if ord(char) >= 0x0980  and ord(char)<=0x09FF :
        print('T')
# Out:
# আ 2438
# T
# ম 2478
# T
# ি 2495
# T
#   32
# ফ 2475
# T
# া 2494
# T
# র 2480
# T
# হ 2489
# T
# ি 2495
# T
# ন 2472
# T
#   32
# ক 2453
# T
# ে 2503
# T
#   32
# ভ 2477
# T
# া 2494
# T
# ল 2482
# T
# ব 2476
# T
# া 2494
# T
# স 2488
# T
# ি 2495
# T

# %%
def bangla_char_in_word(word):
    num_bangla_char = 0
    for char in word:
        if (ord(char) >= 0x0980  and ord(char)<=0x09FF) == True:
            num_bangla_char += 1
    return num_bangla_char

# %%
def is_bangla_sentence (text):
    #first split it with the space
    tot_char_count = 0
    bangla_char_count = 0
    words = text.split()
    for word in words:
        tot_char_count += len(word)
        bangla_char_count += bangla_char_in_word(word)
    #print(tot_char_count,bangla_char_count)
    if(bangla_char_count >= (0.4 * tot_char_count)):
        return True
    return False

# %%
def remove_punctuation(s):
    
 s = re.sub(r'[^\w\s]','',s)
 return s

# %%
def is_english_text(text):
    #first remove the punctuation
    text = remove_punctuation(text)
    #Then split it on whitespace
    words = text.split()
    #And check each word one by one
    total_word_count = len(words)
    english_word_count = 0
    for word in words:
        
        if(word in english_words):
            english_word_count += 1
    
    if(english_word_count >= 0.6*total_word_count):
        return True
    return False

# %%
print(is_bangla_sentence('আমি বাংলাই ko '))
# Out:
# True

# %%
print(guess_language("amar name wasif. ami buet thkey pass korey ekhon uiu tey lecturer"))
# Out:
# lt

# %%
import json
import urllib

def detect_language(text,
    userip=None,
    referrer="http://stackoverflow.com/q/4545977/4279",
    api_key="AIzaSyDE5r11y3X4wGWGefFy6X5oQAZDvVi_y88"):        

    #query = {'q': text.encode('utf-8') if isinstance(text, unicode) else text}
    query = {'q': text.encode('utf-8')}
    if userip: query.update(userip=userip)
    if api_key: query.update(key=api_key)

    url = 'https://www.googleapis.com/language/translate/v2/detect&%s'%(
        urllib.parse.urlencode(query))

    request = urllib.request.Request(url, None, headers=dict(Referer=referrer))
    response = urllib.request.urlopen(request)
  
    print(type(response))
    print(response.read())
        
    string = response.readall().decode('utf-8')
    d = json.load(string)

    if d['responseStatus'] != 200 or u'error' in d['responseData']:
        raise IOError(d)

    return d['responseData']['language']

# %%
#print(detect_language("I am Bangladeshi"))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-14-97c2cbbffbed> in <module>()
# ----> 1 print(detect_language("I am Bangladeshi"))
#
# <ipython-input-13-fbf016014acc> in detect_language(text, userip, referrer, api_key)
#      16
#      17     request = urllib.request.Request(url, None, headers=dict(Referer=referrer))
# ---> 18     response = urllib.request.urlopen(request)
#      19
#      20     print(type(response))
#
# /home/wasifur/anaconda3/lib/python3.5/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# /home/wasifur/anaconda3/lib/python3.5/urllib/request.py in open(self, fullurl, data, timeout)
#     470         for processor in self.process_response.get(protocol, []):
#     471             meth = getattr(processor, meth_name)
# --> 472             response = meth(req, response)
#     473
#     474         return response
#
# /home/wasifur/anaconda3/lib/python3.5/urllib/request.py in http_response(self, request, response)
#     580         if not (200 <= code < 300):
#     581             response = self.parent.error(
# --> 582                 'http', request, response, code, msg, hdrs)
#     583
#     584         return response
#
# /home/wasifur/anaconda3/lib/python3.5/urllib/request.py in error(self, proto, *args)
#     508         if http_err:
#     509             args = (dict, 'default', 'http_error_default') + orig_args
# --> 510             return self._call_chain(*args)
#     511
#     512 # XXX probably also want an abstract factory that knows when it makes
#
# /home/wasifur/anaconda3/lib/python3.5/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# /home/wasifur/anaconda3/lib/python3.5/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     588 class HTTPDefaultErrorHandler(BaseHandler):
#     589     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 590         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     591
#     592 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
def write_as_words(words_in_post, file_object):
    if(len(words_in_post) == 0):
        return
    for i in range(len(words_in_post)-1):
        file_object.write(words_in_post[i] +" ")
    file_object.write(words_in_post[-1] + "\n")

# %%
#this method reads the csv file rows one by one and separates them into three different file for each of Bangla, Benglish and English status

def separate_status_by_language():
    all_status = pd.read_csv("uber_group_posts.csv")
    all_status.columns
    all_status = all_status[["_id","status_message"]]
    stop_words = set(stopwords.words('english'))
    
    domain_words = ['uber','driver','car','trip','ride','fare','time','call','come','go','get','drivers']
 
    
 

    output = open("status_by_language.txt","w+")
    
    bangla_data = open("/media/wasifur/LinuxChotoBhai/Uber_users_in_BD/Uber_code/BTM-master/sample-data/bangla_dataset.txt","w+")
    english_data = open("/media/wasifur/LinuxChotoBhai/Uber_users_in_BD/Uber_code/BTM-master/sample-data/english_dataset.txt","w+")
    banglish_data = open("/media/wasifur/LinuxChotoBhai/Uber_users_in_BD/Uber_code/BTM-master/sample-data/banglish_dataset.txt","w+")
    print(len(all_status))
    ps =   WordNetLemmatizer()
  
   
    count = 0
    #random_indices = np.random.random_integers(0, len(all_status),200)
    #print(sorted(random_indices))
    for i in range(len(all_status)):
        #print(i)
        cur_status = all_status.iloc[i]["status_message"]
        
         #first check whether the status is actually string
        if(isinstance(cur_status,str) == False):
            continue
        count += 1
        #output.write(cur_status)
        table = str.maketrans({key: None for key in string.punctuation})
        cur_status = cur_status.translate(table) 
        #output.write(cur_status)
        
        #print(count)
        #output.write(str(i)+":\n")
        #output.write(cur_status)
        
 
        word_tokens = word_tokenize(cur_status)
        words_in_post = cur_status.split()
 
        
        if(is_bangla_sentence(cur_status)):
            #print("Bangla")
            #output.write("\n output: Bangla")
            
            write_as_words(words_in_post, bangla_data)

        elif(is_english_text(cur_status)):
            #print("English")
            #output.write("\n output: English")
            #print(word_tokens)
            print(str(count)+"\n")
            output.write(' '.join(word_tokens))
            #print(word_tokens)
            filtered_sentence = [ps.lemmatize(w.lower(),'v') for w in word_tokens if w.lower() not in stop_words and ps.lemmatize(w.lower(),'v') not in domain_words]
            print(filtered_sentence)
            #output.write(filtered_sentence))
          
            #print(filtered_sentence)
            write_as_words(filtered_sentence, english_data)
        else:
            #print("Banglish")
            #output.write("\n output: Banglish")
            write_as_words(words_in_post, banglish_data)
        #print("\n\n")
        output.write("\n\n")
    output.close()
    print("count: " +str(count))
    return all_status

# %%
all_status = separate_status_by_language()
#all_status.head()
# Out:
# 7277
# 5
#
# ['ibrahimpur', 'theke', 'ki', 'available', 'anyone', 'idea', 'urgently', 'need', 'info', 'thank', 'advance']
# 6
#
# ['schedule', 'feature', 'available', 'dhaka', 'thank']
# 12
#
# ['want', 'pay', 'credit', 'card', 'fail', 'due', 'error', 'message', 'show', 'pic']
# 17
#
# ['u', 'promo', 'code']
# 19
#
# ['good', 'family', 'attend', 'wed', 'reception', 'party', 'good', 'chauffeur', 'well', 'mannered', 'gentleman', 'helpful', 'family', 'tour']
# 23
#
# ['need', 'promo', 'code']
# 27
#
# ['need', 'promo', 'code']
# 33
#
# ['anyone', 'explain', '370', 'instead', '816x2123x350290']
# 37
#
# ['instal', 'app', 'havent', 'register', 'yet', 'need', 'travel', 'uttara', 'green', 'road', 'way', 'discount', 'nowby', 'code', 'anything', 'friends', 'phone', 'saw', 'charge', 'nearly', '650', 'distance', 'even', 'though', 'roads', 'moderately', 'free']
# 38
#
# ['use', 'since', 'dec', '16', 'take', 'around', '90', 'rid', 'use', 'promo', 'cod', 'till', 'ramadan', 'ramadan', 'promos', 'become', 'bound', 'like', '9', 'am3', 'pm', 'cud', 'avail', 'eid', 'get', 'promo', 'cod', 'kno', 'strong', 'customer', 'cbm', 'platform', 'clue', 'anyone', 'get', 'promo']
# 43
#
# ['better', 'hope', 'best', 'new', 'guideline']
# 44
#
# ['see', 'post', 'problem', 'users', 'drivers']
# 47
#
# ['possible', 'hire', '2', 'simultaneously', 'app']
# 51
#
# ['one', 'please', 'share', 'promo', 'code', 'go', 'take', '2nd']
# 52
#
# ['legend', 'start', 'arrive', 'pickup', 'point', 'precise', 'start', 'unsure', 'since', 'train', 'catch', 'didnt', 'say', 'anything', 'drop', 'designation', 'smelly', 'idea', 'may', 'refund']
# 53
#
# ['dear', 'get', 'refund', 'rupees', 'eita', 'kamne', 'convert', 'korbo', 'bdt', 'te', 'kothai', 'complain', 'korbo', 'ki', 'vabe', 'korbo', 'one', 'please', 'help']
# 55
#
# ['think', 'act', 'guideline', 'rider', 'well', 'passenger']
# 62
#
# ['yet', 'another', 'inspirational', 'story', 'master', 'run', 'smart', 'man', 'gentle', 'behavior', 'make', 'amuse', 'regularly', 'use', 'find', 'bad', 'please', 'dont', 'judge', 'incidents', 'good', 'guy', 'around', 'bad', 'people', 'sector', 'wont', 'stop', 'way', 'life', 'happy', 'ubering', '😊']
# 63
#
# ['dear', 'admin', 'thank', 'lot', 'members', 'accept', 'member']
# 66
#
# ['use', '11252016but', 'unfortunately', 'didnt', 'send', 'promo', 'code', 'till', 'today', 'whats', 'fault', 'plz', 'clarify', 'reason']
# 67
#
# ['promo', 'code', 'please', 'tia']
# 69
#
# ['need', 'promo', 'code', 'tia']
# 70
#
# ['please', 'kindly', 'inbox', 'promo', 'gon', 'na', 'use', 'first']
# 72
#
# ['see', 'rat', 'drivers', 'rat']
# 74
#
# ['isnt', 'anyone', 'group', 'group', 'work', 'bangladesh', 'authorization', 'take', 'action', 'bullshit', 'drivers', 'girl', 'scar', 'use', 'alone', 'emni', 'tei', 'lack', 'security', 'country', 'suppose', 'great', 'help', 'transportation', 'yet', 'turn', 'another', 'threat', 'security', 'fact', 'chelerao', 'toh', 'safe', 'na', 'theres', 'nothing', 'anyone', 'group', 'whats', 'point', 'post', 'help']
# 79
#
# ['anybody', 'get', 'new', 'promo', 'code', 'today', 'urgently', 'need']
# 81
#
# ['need', 'promo', 'code', 'anyone', 'please']
# 82
#
# ['promo', 'code', 'please', 'tia']
# 86
#
# ['take', '2', 'rid', 'today', 'langkawi', 'malaysia', 'mention', 'bangladeshi', 'partner', 'learn', 'many', 'things', 'drivers', 'come', 'pick', '34', 'kms', 'away', 'try', 'tip', 'money', 'rather', 'charge', 'come', 'pretty', 'good', 'friendly']
# 89
#
# ['anyone', 'code', 'plan', '30', 'minutesthanks']
# 92
#
# ['days', 'show', 'longer', 'route', 'higher', 'price', 'customer']
# 93
#
# ['excellent', 'drive', 'courteous', 'never', 'ask', 'destination', 'tip', 'give', '5star', 'lunch', 'iskander', '8801716850227']
# 95
#
# ['family', 'like', 'service', 'much', 'thank', 'lot']
# 97
#
# ['another', 'devastate', 'service', 'ubermy', 'younger', 'sister', 'call', 'mirpur', 'sadarghat', 'yesterdaywhile', 'pick', 'location', 'suddenly', 'disagree', 'take', 'tripin', 'meanwhile', 'sister', 'baggagemy', 'sister', 'didnt', 'make', 'urge', 'driver01787178313', 'let', 'go2nd', 'make', 'another', 'request', 'one', 'move', 'sadarghat', 'lunch', 'terminalthis', 'one', 'diver', 'name', 'kader1970708810', 'come', 'pick', 'upafter', 'go', 'agargao', 'unfortunately', 'inform', 'wont', 'sadarghat', 'max', 'move', 'gulistanhe', 'sadarghat', 'one', 'condition', '1500tkso', 'situation', 'theres', 'alt', 'way', 'urge', 'son', 'mom', 'also', 'stay', 'carso', 'situation', 'customers', 'specially', 'female', 'continue', 'kinda', 'bull', 'shit', 'service', 'day', 'far', 'see']
# 99
#
# ['hi', 'want', 'know', 'promo', 'code', 'provide', 'week', 'tia']
# 102
#
# ['think', 'group', 'discussion', 'relate', 'personal', 'offer', 'wrong']
# 104
#
# ['today', 'request', 'gulshan', '1', 'mirpur', 'bangla', 'college', 'luckily', 'get', 'call', 'ask', 'location', 'say', 'mirpur', '1', 'far', 'pick', 'location', 'though', 'far', 'mirpur', '1', 'bangla', 'college', 'also', 'tell', 'doesnt', 'much', 'gas', 'ask', 'case', 'accept', 'request', 'say', 'right', 'didnt', 'wana', 'ask', 'cancel', 'request', 'refuse', 'didnt', 'cancel', 'request', 'wait', 'moments', 'later', 'call', 'talk', 'rough', 'tell', 'complain', 'cut', 'phone', 'cancel', 'request', 'true', 'caller', 'find', 'search', 'number', 'sorry', 'cant', 'share', 'image', 'first', 'bad', 'experience']
# 106
#
# ['one', 'group', 'tell', 'process', 'use', 'havent', 'use', 'yet', 'urgent']
# 110
#
# ['drivers', 'give', 'u', 'unnecessay', 'low', 'rat', 'dont', 'like', 'ur', 'destination']
# 125
#
# ['call', 'ask', 'double', 'jindabad']
# 135
#
# ['fell', 'painful', 'attitude', 'complain', 'mail', 'result', 'several', 'time', 'face', 'pain', 'full', 'situation']
# 136
#
# ['update', 'credit', 'card', 'number', 'app']
# 137
#
# ['help', 'helpline', 'anyone', 'know', 'helpline', 'number']
# 139
#
# ['book', 'advance', 'tia']
# 144
#
# ['use', 'yesterday', 'good', 'service']
# 145
#
# ['discount', 'code']
# 147
#
# ['dear', 'authority', 'loose', 'control', 'technical', 'system', 'cause', 'damage', 'image', 'bangladesh', 'pls', 'strong', 'manage', 'properly', 'avoid', 'rough', 'practice', 'traditional', 'rental', 'transport', 'management', 'like', 'cng', 'bus', 'etc']
# 155
#
# ['come', 'way', 'back', 'home', 'hand', 'forget', 'mention', 'logbook', 'matter', 'rare', 'uncommon', 'honestly', 'professionalism', 'may', 'alien', 'city', 'breath', 'fresh', 'air', 'know', 'someone', 'like', 'strive', 'stand', 'humility', 'say', 'goodnight', 'peddle', 'away', 'back', 'home']
# 156
#
# ['topic', 'post', 'kind', 'people', 'use', 'group', 'like', 'users', 'bangladesh', 'travellers', 'bangladesh', 'new', 'invention', 'harass', 'girls', 'get', 'today', 'morning', 'irritate', 'shameful', 'way', 'two', 'group', 'much', 'popular', 'believe', 'gentle', 'educate', 'decent', 'people', 'members', 'kind', 'group', 'totally', 'wrong', 'dont', 'understand', 'gather', 'word', 'education', 'manner', '2017', 'yet', 'girls', 'get', 'kind', 'offensive', 'message', 'strangers', 'profile', 'link', 'httpswwwfacebookcomtaskinahamed']
# 157
#
# ['anybody', 'want', 'share', 'today', 'location', 'dhaka', 'valuka', '67am', '01626000099', 'u', 'feel', 'interest']
# 159
#
# ['days', 'problem', 'drivers', 'use', 'cell', 'phone', 'drive', 'sometimes', 'start', 'chit', 'chat', 'phone']
# 166
#
# ['need', 'promo', 'code']
# 168
#
# ['drivers', 'rat', '4', 'better', 'avoid', 'cancel', 'youve', 'understand', 'problem', 'somewhere', 'thats', 'rat', 'low']
# 169
#
# ['end', 'pay', 'tk', '450', 'felt', 'comfort', 'family']
# 170
#
# ['everything', 'perfect']
# 171
#
# ['uberplz', 'carefull', 'selectionnow', 'days', 'many', 'complain', 'drivers', 'bad', 'reputation', 'uberif', 'necessory', 'plz', 'give', 'punishment', 'drivers']
# 177
#
# ['kachpur', 'cover']
# 180
#
# ['select', 'multiple', 'destinations', 'travel']
# 182
#
# ['anyone', 'tell', 'nw']
# 185
#
# ['take', '2', 'mohammadpur', 'rampura', '24', 'june', '245pm', '1', 'show', 'bill', 'taka', '355', 'another', 'show', 'bill', 'taka', '495', 'come', 'together', 'use', 'route', 'traffic', 'also', 'ask', 'time', 'detail', 'receipt', 'respond', 'highly', 'unprofessional', 'service', 'customer', 'care']
# 186
#
# ['another', 'cng', 'foundasking', 'destination', 'tell', 'cancel']
# 187
#
# ['howz', 'even', 'possible']
# 189
#
# ['active', 'eid']
# 195
#
# ['peaceful', 'kolkata']
# 197
#
# ['special', 'today']
# 202
#
# ['skip', 'destination', 'workingwhy']
# 208
#
# ['use', 'penang', 'malaysia', 'get', '50', 'cheaper', 'normal', 'taxi']
# 211
#
# ['yesterday', 'available', 'thats', 'decide', 'use', 'everything', 'neededit', 'take', 'many', 'minutes', 'show', 'find', 'wait', 'many', 'minutes', 'last', '1', 'message', 'saw', 'write', 'ubers', 'use', 'ubers', 'available', 'actually', 'nobody', 'accept', 'availableit', 'offensive', 'dont', 'like', 'kind', 'activities', 'service', 'give', 'right', 'service', 'know', 'reason', 'service', 'become', 'like', '2', 'reason', 'main', '1', 'owners', 'teach', 'give', 'right', 'service', 'drivers', '2', 'drivers', 'cruel', 'think', 'master', 'anything', 'judge', 'feel', 'drivers', 'misbehave', 'judge', '1', 'reason', 'like', 'management', 'dhaka', 'offensive', 'really', 'informations', 'phone', 'number', 'complain', 'office', 'complain', 'let', 'see', 'see', 'blind', 'please', 'share', 'everyonemaybe', 'person', 'help', 'us', 'know', 'informations']
# 217
#
# ['dont', 'know', 'offer', 'rupees', 'register', 'bd', 'never', 'india', 'download', 'app', 'already', 'complain', 'week', 'ago', 'reply😷😷😷😷']
# 226
#
# ['insane', 'daily', 'rider', 'last', 'days', 'unexpected', 'service', 'drivers', 'today', 'request', '4', 'drivers', 'ask', 'go', 'reject', 'destination', 'finally', 'tell', 'tell', 'destination', 'come', 'surprise', 'dhanmondi', 'shonkor', 'monipuriparatejkonipara', 'max', '35', 'km', 'distance', 'insane', '268taka', 'charge', 'every', 'request', 'location', 'give', 'awesomely', 'insane', 'project', 'hell']
# 227
#
# ['roam', 'around', '20', 'minutes', 'pick', 'upi', 'dont', 'understand', 'drivers', 'suppose', 'know', 'use', 'gps', 'na', 'holay', 'job', 'pai', 'ki', 'bhabe']
# 228
#
# ['available', 'tomorrow', 'eid', 'day']
# 231
#
# ['many', 'time', 'invitation', 'code', 'work', 'one', 'user']
# 233
#
# ['😂☺😊']
# 238
#
# ['anyone', 'tell', 'credit', 'process', 'get', 'tia']
# 240
#
# ['nothing', 'love', '❤️']
# 242
#
# ['plz', 'watch', 'fun', 'plz', 'subscribe', 'chnl', 'share', 'video']
# 244
#
# ['yesterday', '24june2017', 'saturday', 'travel', 'bashundhara', 'shop', 'mal', 'home', 'first', 'ask', 'cng', '3', 'wheeler', 'ask', 'tk', '250', 'servuce', 'excellent', 'good', 'really', 'happy']
# 245
#
# ['post', 'create', 'awareness', 'u', 'ever', 'scumbag', 'ready', 'like', 'experience']
# 247
#
# ['really', 'dont', 'see', 'point', 'engage', 'many', 'faltu', 'reasonsvirey', 'taxi', 'neither', 'alternative', 'plain', 'simple', 'help', 'money', 'u', 'enough', 'else', 'please', 'find', 'regular', 'transportation', 'btw', 'favorite', 'transportation', 'rickshaw', 'dont', 'think', 'rich', 'spoil', 'brat', '😁😁😁']
# 250
#
# ['first', 'ever', 'request', 'gopibagh', '3rd', 'lane', 'uttara', 'house', 'build', 'initially', 'show', '706', 'bdt', 'start', 'reach', 'destination', 'tell', 'take', 'calculate', 'due', 'network', 'issue', 'ask', 'pay', 'charge', 'show', 'initially', '706', 'bdt', 'pay', 'receipt', 'show', '170', 'bdt', 'call', 'agree', 'well', 'charge', 'show', '170', 'bdt', 'say', 'call', 'say', 'due', 'technical', 'issue', 'charge', 'adjust', 'soon', 'customer', 'message', 'soon', 'solve', 'sure', 'actually', 'happen', 'want', 'know', 'correct']
# 251
#
# ['point', 'even', 'tire', 'sick', 'health', 'wise', 'still', 'write', 'write', 'someone', 'run', 'bangladesh', 'today', 'wife', 'request', 'laws', 'tejkonipara', 'give', 'drivers', 'information', 'pick', 'us', 'wife', 'two', 'children', '1', '3', 'beat', 'crazy', 'look', 'dirty', 'vehicle', 'keep', 'shut', 'felt', 'unsafe', 'kid', 'story', 'begin', 'rid', 'cow', 'cart', 'unfriendly', 'smelly', 'constantly', 'cell', 'phone', 'use', 'un', 'welcome', 'languages', 'front', 'kid', 'shout', 'phone', 'thenhits', 'cng', 'scooter', 'behind', 'concentrate', 'cell', 'phone', 'get', 'go', 'guess', 'break', 'wouldnt', 'start', 'arrogant', 'wouldnt', 'bother', 'even', 'inform', 'us', 'anything', 'instead', 'shut', 'air', 'condition', 'lock', 'doors', 'windows', 'get', 'vehicle', 'somehow', 'able', 'unlock', 'door', 'get', 'say', 'guy', 'take', 'rickshaw', 'show', 'cash', 'screen', 'say', '200', 'take', 'serious', 'even', 'brand', 'new', 'mercedes', 'benz', 'wouldnt', 'pay', '200taka', '4', 'k', 'distance', 'whole', 'like', 'one', 'decide', 'pay', 'make', 'example', 'tech', 'proper', 'lesson', 'shouldnt', 'main', 'final', 'question', 'option', 'emergency', 'contact', 'number', 'biggest', 'taxi', 'company', 'world', 'daily', 'customer', 'sadly', 'sell', 'trust', 'serve', 'purpose']
# 254
#
# ['want', 'partnerdriver', 'last', '25', 'days', 'actual', 'earn', 'expenditure', 'appoint', 'contract', 'deduct', 'expenditure', 'fuelgasmobileany', 'maintenancemobile', 'billgerrage', '40', 'net', 'profit', 'remain', 'online', '1012', 'hours', 'daily', 'register', 'private', 'non', 'commercial', 'may', 'violation', 'law', 'registration', 'cost', 'around', '8000tk', 'annually', 'owner', 'pay', 'income', 'tax', 'every', 'year', 'ait', 'adjust', 'total', 'tax', '29', 'may22', 'june', '25', 'days', 'earn', '79166', 'octane', '1500', 'cng', '16118', 'maintenancemobileengine', 'oilmisc', 'cost', '4600', 'mobiledata', '729', 'gerrageguard', '1660', 'total', 'cost', '24607', 'profit', '54559', 'profit', 'share', 'owner60', '32735', 'driver40', '21824']
# 256
#
# ['use', 'eid', 'days', 'id', 'like', 'know', 'availability', 'cars', 'insight']
# 258
#
# ['always', 'confuse', 'distance', 'calculation', 'price', 'look', 'arrival', 'place', 'front', 'arrival', 'place', 'u', 'turn', 'really', 'dont', 'need', 'long', 'back', 'charge', 'come', 'ridiculous', 'please', 'fix', 'app', 'manual', 'calculation', 'system']
# 262
#
# ['havent', 'receive', 'message', 'promo', 'sms', 'week', 'though', 'take', 'regular', 'rid', 'anyone', 'advise', 'could', 'possible', 'reason', 'behind', 'thank']
# 267
#
# ['kind', 'dumb', 'route', 'need', 'square', 'hospital', 'see', 'route', 'take', 'detour', 'hospital', 'clearly', 'straight', 'line']
# 279
#
# ['offtopic', 'anyone', 'will', 'donate', 'cancer', 'patient', 'positive', 'blood', 'dhk', 'plz', 'knock', '01711082645', 'urgent']
# 280
#
# ['use', 'smallshort', 'distance', 'road', 'cross', 'issue', 'time', 'urgency', 'drivers', 'patient', 'enough', 'anyone', 'experience', 'please', 'share', 'thank']
# 282
#
# ['ki', 'eid', 'er', 'discount', 'promotion', 'dont', 'apply', 'send', 'request', 'anyone', 'know', 'reason']
# 286
#
# ['need', '10', 'hours', 'dayanyone', 'interest', 'inbox', 'comment']
# 288
#
# ['well', 'describe', 'pretty', 'similar', 'country']
# 291
#
# ['helpline', 'number', 'bangladesh', 'need', 'report', 'also', 'ask', 'detail', 'look', 'forward', 'take', 'legal', 'action', 'thank']
# 293
#
# ['tell', 'last', 'rider', 'request', 'despite', 'heavy', 'traffic', 'respond', 'really', 'hardworking', 'high', 'rat', 'go', 'beyond', 'every', 'rider', 'imagine', 'frustration', 'upon', 'arrival', 'call', 'person', 'inform', 'forget', 'cancel', 'take', 'rickshaw', 'home', 'selfish', 'idiotic', 'behaviours', 'riders', 'need', 'address', 'well', 'needle', 'say', 'take', 'phone', 'make', 'complaint', 'moron', 'cant', 'civil', 'dont', 'leave', 'house']
# 294
#
# ['wife', 'weird', 'shock', 'experience', 'yesterday', 'call', 'jamuna', 'future', 'park', 'destination', 'mirpur1', 'much', 'familiar', 'way', 'mirpur1', 'regular', 'passenger', 'route', 'without', 'notice', 'go', 'opposite', 'mirpur', 'ie', 'towards', 'abdullahpur', 'suddenly', 'find', 'azampur', 'ask', 'azampur', 'ask', 'want', 'though', 'set', 'destination', 'mirpur', 'tell', 'several', 'time', 'want', 'mirpur1', 'uturned', 'start', 'argue', 'unnecessary', 'things', 'already', '10', 'pm', 'clock', 'become', 'much', 'afraid', 'disappoint', 'front', 'airport', 'ask', 'pay', '500', 'takas', 'get', 'fortunately', 'police', 'sergeant', 'nearby', 'loudly', 'call', 'fortunately', 'listen', 'explain', 'situation', 'ask', 'help', 'police', 'officer', 'manage', 'vehicle', 'manage', 'one', 'come', 'back', 'home', 'safely', 'much', 'disappoint', 'disturb', 'able', 'take', 'action', 'drive', 'without', 'handover', 'police', 'sergeant', 'inform', 'incident', '12', 'hours', 'pass', 'still', 'reply', 'anything', 'far', '’', 'much', 'bad', 'experience', 'till', 'except', 'drivers', 'argue', 'unnecessary', 'things', 'one', 'cheat', 'never', 'complain', 'incidents', 'natural', 'behavior', 'service', 'providers', 'bangladesh', 'still', 'good', 'rat', 'passenger', '48', 'mean', 'drivers', 'happy', 'yesterday', '’', 'experience', 'highly', 'shock', 'still', 'know', 'motive', 'accord', 'case', '1', 'actually', '’', 'understand', 'drive', 'mind', 'try', 'force', 'notice', 'make', 'mistake', 'case', 'right', 'behavior', 'would', 'accept', 'mistake', 'drop', 'anybody', 'hisher', 'destination', 'without', 'charge', 'definitely', '2', 'intentionally', 'do', 'think', 'woman', 'fraud', 'forcefully', 'charge', 'money', '3', 'might', 'things', 'mind', 'really', 'worry', 'case', 'follow', 'users', 'bangladesh', 'group', 'post', 'see', 'dramas', 'happen', 'people', 'argue', 'way', 'pay', 'monthly', 'attack', 'people', 'report', 'bad', 'experience', 'also', 'people', 'highly', 'keep', 'mind', 'multinational', 'company', 'offer', 'service', 'us', 'use', 'service', 'properly', 'ie', 'misuse', 'service', 'bring', 'good', 'us', 'act', 'way', 'could', 'keep', 'security', 'safety', 'first', '’', 'profit', 'owner', '’', 'profit', 'owner', '’', 'allow', 'profit', 'commit', 'safety', 'security', 'otherwise', 'leave', 'like', 'ceo', 'resign', 'yesterday', 'experience', 'several', 'drivers', 'behave', 'properly', 'passengers', '’', 'know', 'use', 'map', 'train', 'owners', 'buy', 'without', 'notice', 'point', 'hand', 'personally', 'train', 'several', 'drivers', 'use', 'map', 'behave', 'properly', 'passengers', 'think', 'also', 'drivers', 'would', 'suppose', 'train', 'passengers', 'use', 'properly', 'without', 'proper', 'train', '’', 'able', 'might', 'need', 'day', 'train', 'things', 'nighter', 'owners', 'want', 'take', 'responsibility', 'think', 'many', 'untold', 'stories', 'passengers', 'humiliate', 'drivers', 'much', 'tech', 'people', 'post', 'social', 'media', 'concern', 'issue', 'go', 'another', 'sinbad', '’', 'old', 'man', 'us', 'sure', 'soon']
# 295
#
# ['problem', '1', 'receive', 'request', 'immediately', 'start', 'without', 'pick', 'problem', '2', 'call', 'sound', 'sleepy', 'talk', 'bite', 'harsh', 'problem', '3', 'start', 'already', 'couldnt', 'cancel', 'call', 'request', 'cancel', 'cause', 'couldnt', 'another', 'problem', '4', 'hassle', 'receive', 'receipt', 'amount', 'base', 'problem', '5', 'try', 'give', 'feedback', 'couldnt', 'find', 'relevant', 'scope', 'app', 'dont', 'spare', 'say', 'u', 'didnt', 'lose', 'money', 'complain', 'believe', 'problem', 'share', 'least', 'whether', 'operation', 'technical']
# 308
#
# ['man', 'open', 'door', 'wife', 'either', 'new', 'new', 'wife', 'need', 'new', 'port', 'please', 'inbox', 'model', 'give', 'feedback']
# 318
#
# ['home', 'alone', 'wake', 'even', 'think', 'manage', 'iftar', 'hassle', 'randomly', 'check', 'app', 'place', 'order', 'voilatehari', 'straight', 'home', 'within', '10', 'mins', 'thank', 'lot', 'uberiftar']
# 320
#
# ['within', '1', 'min', 'get', 'two', 'different', 'upfront', 'amount', 'total', '194', 'tk', 'difference', 'continuously', 'change']
# 321
#
# ['things', 'happen', 'every', 'single']
# 323
#
# ['take', 'first', 'didnt', 'receipt', 'mail', 'wht']
# 325
#
# ['rcvd', 'ask', 'destination', 'ignore', 'placei', 'ask', 'cancel', 'say', 'cancel', '30', 'minasshole', 'guy']
# 328
#
# ['idea', 'ubers', 'availablilty', 'eid', 'afternoons', 'even']
# 332
#
# ['use', 'pathao', 'service', 'sometime', 'beside', 'anybody', 'idea', 'biker', 'service', 'better', 'pathao', 'dhaka', 'riders', 'sam']
# 335
#
# ['wan', 'na', 'knowuber', 'er', 'ki', 'peck', 'pick', 'er', 'kono', 'issue', 'ase']
# 336
#
# ['😂😂😂']
# 344
#
# ['cant', 'see', 'breakdown', 'like', 'km', 'base', 'update', 'app', 'also', 'solution', 'yet', 'find', 'anybody', 'help']
# 346
#
# ['ki', 'day', 'day', 'bara', 'bare', '1st', 'uttara', 'jashim', 'uddin', 'theke', 'bashundhara', 'ra', '225', '2nd', '255', '5th', '270', 'last', 'yesterday', '290', 'jashimuddin', 'bashundhara', 'road', 'always', 'free', 'sometimes', 'slight', 'traffic', 'single', 'shock', 'high', 'charge', 'day', 'day', 'think', 'one', 'kind', 'cheat']
# 348
#
# ['ajk', 'akta', 'thaka', 'message', 'palam', 'oder', 'office', 'bondho', 'anyone', 'help', 'mean', 'update', 'paper', 'already', 'give', 'run', 'last', '3', 'month']
# 351
#
# ['today', 'first', 'day', 'rat', '1', 'family', 'take', 'banasree', 'kollanpur', 'usual', 'use', 'card', 'complete', 'say', 'rudely', 'make', 'morning', 'bad', 'cause', 'card', 'payment', 'transaction', 'single', 'penny', 'also', 'rat', 'poor', 'rat', 'go', '472', '464']
# 353
#
# ['policy', 'first']
# 358
#
# ['front', 'n', 'mean', 'escape', 'destination']
# 361
#
# ['isnnt', 'chittagong', 'service', 'cng', 'drivers', 'rip', 'us', 'badly']
# 366
#
# ['recently', 'seem', 'show', 'longer', 'distance', 'route', 'rather', 'direct', 'shortcut', 'also', 'change', 'route', 'take', 'another', 'way', 'bill', 'come', 'high', 'think', 'poor', 'mind', 'people', 'enter', 'management', 'make', 'type', 'cheat', 'rule']
# 367
#
# ['check', 'rat', 'passenger', 'tia']
# 372
#
# ['password', 'recovery', 'option', 'use', 'phone', 'number', 'months', 'back', 'sign', 'give', 'cell', 'number', 'email', 'id']
# 374
#
# ['setup', 'schedule', 'need', 'book', 'airport', '6', 'clock', 'morning', 'please', 'let', 'knowthanks', 'advance']
# 379
#
# ['anybody', 'explain', 'ne', 'free', 'code', 'work', 'mean', 'use', 'code', 'twice']
# 381
#
# ['check', 'rat']
# 382
#
# ['check', 'discount']
# 385
#
# ['anyone', 'office', 'bd']
# 391
#
# ['face', 'thing', 'well']
# 393
#
# ['😂😂😂😂']
# 397
#
# ['well', 'guess', 'need', 'introduction', 'dhaka', 'p', 'p']
# 401
#
# ['like', 'grameenphone', 'discount', 'frame', 'put', 'onto', 'frame', 'p', 'people', 'mind', 'duck', 'corporate', 'business', 'policies', 'however', 'already', 'stop', 'use', 'emergencies']
# 406
#
# ['nice', 'read']
# 407
#
# ['ceo', 'travis', 'kalanick', 'resign', '’', 'embattle', 'ceo', 'travis', 'kalanick', 'resign', 'ridesharing', 'company', 'help', 'find', '2009', 'follow', '“', 'shareholder', 'revolt', '”', 'lead', '’', 'prominent', 'investors', 'new', 'york', 'time', 'report', 'spokesperson', 'confirm', 'techcrunch', 'kalanick', 'step', 'full', 'news', 'link', 'check', '1st', 'comment']
# 414
#
# ['awosome', 'also', 'much', 'friendly', 'much', 'short', 'distance', 'bt', 'promo', 'code', 'r', 'last', 'date', 'silo', 'tai', 'use', 'krlam', 'unr', 'kisu', 'ktha', 'amr', 'whole', 'lyf', 'mne', 'thaakbe', 'may', 'allah', 'bless', 'u', 'sha', 'allah', 'abr', 'dkha', 'hbe']
# 416
#
# ['promo', 'cod', 'week']
# 417
#
# ['গাড়ী', 'নং', '১১৯৯৫২', 'mitsubishi', 'lancer', 'এর', 'মালিক', 'এর', 'উদ্দেশ\u200d্যে', 'বলছি', 'আপনার', 'ড্রাইভার', 'বিপ্লব', 'এর', 'মতে', 'আপনি', 'ফকিন্নি', 'এইজন\u200d্য', 'উবার', 'এ', 'গাড়ী', 'দিয়েছেন', '।', 'আর', 'যাত্রীদের', 'সাথে', 'উনার', 'ব\u200d্যবহার', 'আরো', 'ভয়ংকর।', 'occurrences', 'soon', 'believe', 'continue', 'kind', 'behavior', 'change', 'withdraw', 'first', 'week', 'rat', '42', '4', 'soon', 'dont', 'think', 'beneficial', 'way', 'think', 'inform', 'rest', 'happy', 'ubering']
# 421
#
# ['knowledge', 'post', 'expert', 'ekta', 'personal', 'example', 'dei', 'one', 'day', 'request', 'usual', 'accept', 'request', 'meet', 'pick', 'point', 'january', 'late', 'december', '2016', 'honda', 'civic', '2016', 'interior', 'modify', 'use', 'cars', 'like', 'proton', 'saga', 'perodua', 'axia', 'myvi', 'etc', 'good', 'cars', 'dont', 'take', 'wrong', 'heres', 'conversation', 'hello', 'sir', 'hi', 'name', 'fine', 'fine', 'sir', 'thank', 'great', 'thank', 'bole', 'rakha', 'bhalo', 'je', 'ar', 'rider', 'er', 'moddhe', 'ekta', 'chat', 'howa', 'er', 'policy', 'er', 'moddhe', 'pore', 'dont', 'mind', 'ask', 'sirhe', 'senior', 'work', 'regular', 'basis', 'haha', 'really', 'work', 'tmobile', 'former', 'employer', 'dell', 'company', 'wow', 'ki', 'ar', 'korbo', 'eto', 'shundor', 'gari', 'conversation', 'go', 'reach', 'destination', 'promofree', 'thank', 'sir', 'smile', 'great', 'day', 'ahead', 'pleasure', 'use', 'least', 'twice', 'day', 'back', 'kualalampur', 'almost', 'every', 'get', 'take', 'part', 'job', 'never', 'felt', 'someone', 'illiterate', 'lack', 'manners', 'reason', 'share', 'post', 'drivers', 'dhaka', 'actual', 'drivers', 'know', 'educate', 'uneducated', 'people', 'bad', 'sth', 'drivers', 'drive', 'cars', 'cost', '2025', 'lacs', 'expect', 'treat', 'family', 'way', 'respect', 'boss', 'expect', 'greet', 'smile', 'dont', 'expect', 'master', 'app', 'map', 'ridewhy', 'bother', 'talk', 'without', 'reason', 'bless', 'city', 'people', 'bus', 'stand', 'day', 'everyday', 'keep', 'complain', 'maybe', 'one', 'day', 'pack', 'away']
# 423
#
# ['try', 'hold', 'quite', 'exhaust', 'day', 'hour', 'days', 'back', 'pay', '110', 'tk', 'farmgate', 'mohakhali', 'dohs', 'well', 'say', 'good', 'old', 'days', '😠']
# 427
#
# ['finally', 'cave', 'add', 'tip', 'option', 'app', 'major', 'reversal', 'part', '’', '‘', '180', 'days', 'change', '’', 'aim', 'improve', 'relations', 'drivers', 'important', 'first', 'step', 'toward', 'fair', 'ridehail', 'industry', '”', 'httpsmfacebookcomstoryphpstoryfbid1673590426002393substoryindex0id142088335819284']
# 429
#
# ['main', 'problem', 'havent', 'yet', 'understand', 'concept', 'service', '1', 'isnt', 'taxi', 'service', 'provider', 'technological', 'solution', 'connect', 'rider', 'vehicle', 'cant', 'compare', 'cngtaxi', 'service', '2', 'cheaper', 'taxi', 'cab', 'officially', 'costlier', 'cng', 'little', 'tricky', 'able', 'promos', 'always', 'sometimes', 'even', 'cheaper', 'rickshaw', '3', 'even', 'ownersocially', 'well', 'renowned', 'person', 'doesnt', 'need', 'profession', 'better', 'treat', 'like', 'cngyour', '4', 'cant', 'cng', 'phonewe', 'wait', 'road', 'hours', 'bargain', 'beg', 'take', 'us', 'expect', 'reach', 'doorstep', 'insaned', 'trafic', 'city', 'justify', 'cooperative', '5', 'doesnt', 'complain', 'hotline', 'report', 'issue', 'mobile', 'app', 'careful', 'take', 'action', 'short', 'tell', 'personal', 'experience', '6', 'value', 'add', 'lifestyle', 'service', 'give', 'us', 'ease', 'comfort', 'travel', 'bless', 'city', 'scarcity', 'public', 'transport', 'educate', 'riders', 'cz', 'new', 'thing', 'bangladesh', 'let', 'grateful', 'otherwise', 'almighty', 'might', 'take', 'away', 'might', 'problems', 'system', 'system', 'rectify', 'সব', 'কথার', 'শেষ', 'কথা', 'ভাল', 'না', 'লাগলে', 'use', 'কইরেন', 'না', 'যাদের', 'ভালো', 'লাগে', 'তাদের', 'use', 'করতে', 'দেন।', 'এমনেই', 'দেশে', 'ভালো', 'কিছু', 'হয়', 'না', 'হইলেও', 'যদি', 'পিছনে', 'পড়েন', 'কেম্নে', 'কি', 'ভাইবোনেরা']
# 430
#
# ['rarely', 'positive', 'review', 'among', 'hatred', 'saw', 'news', 'fee']
# 439
#
# ['cancel', 'accept', 'cancellation', 'save', 'anywhere']
# 445
#
# ['ubers', 'rise', 'day', 'day', 'distance', 'cost', '150180', 'weeks', 'ago', 'today', 'find', '275with', 'discount', '😒😒😒', 'show', 'bangladeshi', 'class', 'day', 'day']
# 456
#
# ['😂😂😂😂😂']
# 463
#
# ['check', 'activation', 'promotional', 'code', 'everytime', 'want', 'put', 'promo', 'say', 'another', 'promo', 'already', 'activate', 'never', 'discount', 'till', 'tia', 'advice']
# 469
#
# ['dear', 'authority', 'elder', 'brother', 'along', 'father', 'go', 'badda', 'link', 'road', 'anwara', 'medical', 'service', 'dhanmondi', '280', 'tk', 'ok', 'per', 'projection', 'unfortunately', 'uhen', 'come', 'back', 'path', 'projection', '274', 'tk', 'completion', 'become', '825tk', 'discount', 'rate', 'become', '725', 'tk', 'possible', '10km', 'become', '825tk', 'take', 'extra', 'traffic', 'jam', 'thats', 'may', 'extra', 'amount', 'add', 'wait', 'detail', 'pic', 'ripon', 'pn', '01716554465', 'request', 'elder', 'brother', 'namedshahadath', 'hossainpn', '01722117789', 'please', 'take', 'necessary', 'step', 'refund', 'extra', 'money', 'thank']
# 470
#
# ['today', 'morning', 'experience', 'connect', 'directly', 'ask', 'destination', 'inform', 'pick', 'inform', 'refuse', 'tell', 'short', 'distance', 'minutes', 'letter', 'rat', '1', '🌟', 'type', 'behaviour', 'first', 'face', 'problem', 'name', 'anowar', 'mobile', '📱', '01949500239']
# 472
#
# ['peaceful', 'month', 'ramadan', 'enrage', 'say', 'least', 'bashundhara', 'ra', 'baridhara', '85am', 'apne', 'kothay', 'bhaiyakotokkhon', 'lagte', 'pare', 'bhaiya', 'long', 'might', 'take', 'solely', 'ask', 'traffc', 'congestions', 'baridhara', 'yes', 'see', 'bashundhara', 'ra', 'amar', 'onek', 'shomoy', 'lagbe', 'apne', 'cancel', 'koren', 'go', 'take', 'cancel', 'apne', 'dekhechen', 'ami', 'kothai', 'tahole', 'keno', 'accept', 'korlen', 'saw', 'accept', 'baridhara', 'far', 'bashundhara', 'ra', 'ami', 'cancel', 'korle', 'amar', 'onek', 'shomoshsha', 'hobe', 'go', 'problem', 'cancel', 'amar', 'kono', 'problem', 'nai', 'wait', 'korte', 'problem', 'apnar', 'apni', 'cancel', 'koren', 'dont', 'problems', 'wait', 'problem', 'cancel', 'ami', 'ashte', 'pari', 'tahole', 'ami', 'ekhan', 'theke', 'korbo', 'ashbo', 'start', 'apnader', 'bujha', 'uchit', 'amader', 'kotha', 'ektu', 'taka', 'dile', 'ki', 'hoy', 'understand', 'problems', 'matter', 'spend', 'bite', 'ami', 'complain', 'korbo', 'ill', 'complain', 'koren', 'kono', 'labh', 'nai', 'ahead', 'wont', 'make', 'difference', 'something', 'effect', 'go', 'take', 'cng', 'cancel', '57', 'minutes', 'take', 'screenshot', 'go', 'cancel', 'complain', 'app', 'cancellation', 'dont', 'know', 'outrage', 'threaten', 'blackmail', 'could', 'fearless', 'dailogues', 'accord', 'accountability', 'one', 'anything', 'treat', 'way', 'talk', 'another', 'manner', 'anyone', 'else', 'matter', 'need', 'selective', 'drivers', 'unacceptableubersupport', 'uberheadoffice', 'uberbangladesh', 'uberindia']
# 475
#
# ['know', 'chopper', 'service', 'well']
# 478
#
# ['dile', 'per', 'month', 'net', 'income', 'koto']
# 482
#
# ['deny', 'destination', '11', 'pm', '160617']
# 483
#
# ['go', 'paribag', 'golf', 'club', '8', 'pm', 'trafic', 'jam', '310', 'tk', 'return', 'fair', '420', 'tk', '11pm', 'road', 'free', 'could', 'u', 'pls', 'clarify', 'problem']
# 489
#
# ['love', '2', 'still', 'find', '8', 'cars', 'nearme', '😃']
# 491
#
# ['take', 'today', 'mohammadpur', 'house', 'society', 'gulshan', '1', 'nice', 'decorate', 'toyota', 'axio', 'nice', 'behaviour', 'awesome', 'hailuber', 'uberon']
# 494
#
# ['respect', 'two', 'way', 'street', 'problem', 'drivers', 'write', 'big', 'big', 'post', 'fb', 'likesreacts', 'social', 'media', 'justice']
# 501
#
# ['wretched', 'guy', 'take', '4', 'time', 'longer', 'route', 'ofcourse', 'ignore', 'suggest', 'one', 'collagegate', 'mohammadia', 'house', 'limit', '38', 'week', 'pregnant', 'wife', 'way', 'home', 'medical', 'checkup', 'mother', 'since', 'mother', 'new', 'dhaka', 'wife', 'feel', 'well', 'suggest', 'remain', 'silent', 'route', 'pay', 'much', 'demandsover', 'phone', 'really', 'helpless', 'sit', 'office', 'hear', 'mother', 'pregnant', 'wifes', '2', 'hours', 'long', 'agony', 'second', 'surprise', 'give', 'complain', 'ask', 'refund', '7', 'june', 'send', '2', 'reminders', 'close', 'complain', 'without', 'give', 'single', 'reply', 'wow', 'new', 'version', 'thugs', 'real', 'face']
# 513
#
# ['first', 'today', 'satisfy', 'question', 'make', 'profitsincome']
# 515
#
# ['affiliate', 'vehicles', 'business', '20', 'years', 'old', 'worth', 'full', 'business', 'create', 'customer', 'dissatisfaction']
# 516
#
# ['fly', 'taxi', 'come', 'dubai', 'usa']
# 517
#
# ['follow', 'today', 'mornings', 'incident', 'tweet', 'well', 'bd', 'respond', 'communication', 'screenshot', 'glad', 'corrective', 'measure', 'take', 'incident', 'pay', 'attention', 'prevention', 'better', 'cure', 'isnt', 'nonetheless', 'thank', 'uberheadoffice', 'uberbangladesh', 'uberbd']
# 551
#
# ['today', 'leave', 'iphone', 'use', 'service', '5', 'minutes', 'call', 'number', 'mr', 'miyer', 'receive', 'tell', 'wait', 'drop', 'come', 'location', 'within', '4', 'mins', 'return', 'phone', 'really', 'well', 'mannered', 'guy', 'im', 'grateful', 'honesty', 'really', 'appreciate', 'work']
# 552
#
# ['get', 'promo', 'ananodo', '30', 'want', 'add', 'one', 'payment', 'work', 'tell', 'promo', 'corect']
# 557
#
# ['khilketh', 'banani', 'road', '11', 'look', 'route']
# 558
#
# ['good', 'even', 'look', 'expert', 'wan', 'na', 'buy', 'register', 'please', 'knock', 'back', 'think', 'help']
# 560
#
# ['update', 'shanta', 'ghoshsumon', 'sarker', 'incident', 'people', 'without', 'authentic', 'information', 'please', 'avoid', 'fiction', 'abuse']
# 566
#
# ['experience', 'soo', 'good', 'drivers', 'friendly', 'helpfull']
# 578
#
# ['ive', 'use', 'many', 'days', '3', 'countries', 'never', 'face', 'horrific', 'conversation', 'like', 'today', 'accept', 'request', 'could', 'see', 'stand', 'still', '5', 'minutes', 'call', 'ask', 'give', 'address', 'roughly', 'talk', 'didnt', 'expect', 'right', 'request', 'im', 'sure', 'theres', 'rule', 'anyway', 'say', 'word', 'say', 'could', 'also', 'জিহ্বা', 'ছিঁড়ে', 'ফেলব', 'শালার', 'মাগী', 'scream', 'disgust', 'scream', 'felt', 'ill', 'tear', 'apart', 'could', 'reach', 'would', 'someone', 'say', 'thing', 'conversation', 'cancel', 'right', 'moment', 'guess', 'cant', 'find', 'detail', 'im', 'share', 'number', 'name', 'hop', 'ladies', 'avoid', 'name', 'shakayet', 'mobile', '8801718838405', 'ps', 'dont', 'know', 'report', 'without', 'detail', 'pls', 'advice']
# 579
#
# ['take', 'step', 'happy']
# 584
#
# ['refund', 'credit', 'one', 'claim', 'credit', 'use', 'automatically', 'next']
# 585
#
# ['till', 'today', 'morning', 'rat', '5', '5', 'today', 'find', 'rat', '491', 'give', '5', 'star', 'dont', 'know', 'give', 'lower', 'rat', 'wish', 'could', 'change', 'drivers', 'rat', 'ekkere', '0', 'dia', 'ditam']
# 592
#
# ['thank', 'accept', 'btwuber', 'drivers', 'start', 'new', 'trendafter', 'receving', 'ask', 'koi', 'jaben', 'disgust']
# 594
#
# ['yesterday', 'morning', 'come', 'technical', 'gulshan2', 'early', 'morning', '620', 'wonderful']
# 596
#
# ['complain', 'service', 'ubar', 'drivers', 'link']
# 597
#
# ['mean', 'one', 'know']
# 601
#
# ['wonder', 'increase', 'suddenly', 'since', '2', 'days', 'one', 'else', 'felt']
# 603
#
# ['extort', 'today', 'always', 'support', 'drivers', 'even', 'shuman', 'sarker', 'find', 'behavior', '8801776008535', 'avoid', 'best', 'partner', 'riders']
# 604
#
# ['possible', 'two', 'different', 'promo', 'cod', 'applicable', 'frame']
# 607
#
# ['hi', 'want', 'hire', 'mohammadpur', 'gabtoli', 'bus', 'tarminal', 'per', 'process', 'pick', 'destination', 'show', 'map', 'quite', 'unusal', 'instead', 'take', 'straight', 'road', 'suggest', 'long', 'road', 'malfunction', 'rule', 'since', 'know', 'take', 'straight', 'road', 'n', 'prefer', 'please', 'help', 'understand']
# 608
#
# ['till', 'didnt', 'face', 'major', 'problem', 'except', 'কই', 'যাইবেন', 'পুরান', 'ঢাকা', 'অইখানে', 'যামু', 'না', 'কেন্সেল', 'করে', 'দেন', 'cant', 'try', 'ignore', 'question', 'drivers', 'literally', 'force', 'tell', 'destination', 'today', 'call', 'basundhara', 'city', 'accept', 'request', 'enter', 'tell', 'bhai', 'puran', 'dhaka', 'jabo', 'na', 'leave', 'place', 'didnt', 'food', 'fast', 'deny', 'j', 'face', 'problem', '56', 'cars', 'take', 'rickshaw', 'come', 'home']
# 610
#
# ['fuck', 'wrong', 'standardize', 'service', 'wont', 'long', 'pack', 'leave']
# 614
#
# ['apparently', 'many', 'conflict', 'passengers', 'riders', 'cant', 'solution', 'like', 'arrange', 'cctv', 'camera', 'dashboardinner', 'rearview', 'mirror', 'fact', 'may', 'require', 'owners', 'install', 'camera', 'proper', 'video', 'storage', 'part', 'official', 'contract', 'limitation', 'theory']
# 616
#
# ['hellocould', 'anyone', 'provide', 'promo', 'code', 'help', 'would', 'much', 'appreciatedthanks']
# 623
#
# ['guy', 'yesterday', 'go', 'gulshan', '1', 'iccb', 'bashundhara', 'around', '7kms', '13', 'mins', 'away', '540', 'tk', 'clue', 'would', 'happen', 'anyone', 'tell', 'way', 'let', 'know', 'discrepancy']
# 625
#
# ['😂😂']
# 626
#
# ['anyone', 'know', 'last', 'series', 'accept', 'regulations', 'model', 'thank', 'advance']
# 627
#
# ['report', 'issue', 'regard', 'way', 'report', 'app', 'send', 'email', 'well', 'could', 'please', 'tell', 'email', 'address']
# 630
#
# ['find', 'three', 'excellent', 'drivers', 'last', 'two', 'days', 'polite', 'well', 'mannered', 'fuss', 'credit', 'cardcash', 'issue', 'also', 'good', 'clean', 'cars', 'good', 'ac']
# 632
#
# ['minutes', 'ago', 'three', 'refuse', 'destination']
# 633
#
# ['use', 'today', 'take', 'bill', 'credit', 'card', 'soon', 'confiirmed', 'reverse', 'payment', 'try', 'take', 'additional', 'payment', 'payment', 'get', 'rejectednow', 'question', 'pay', 'money', 'another', 'thing', 'first', 'suppose', 'discount', 'havent']
# 635
#
# ['route', 'plan', 'mrnafis', 'explanation']
# 644
#
# ['dear', 'enjoy', 'service', 'please', 'keep', 'dont', 'give', 'wish', 'best']
# 649
#
# ['need', 'early', 'morning', 'flight', 'safe']
# 654
#
# ['im', 'use', 'service', 'since', 'last', '4months', 'frequently', 'think', 'drivers', 'good', 'start', 'conversation', 'show', 'due', 'respect', '😊']
# 656
#
# ['lot', 'people', 'make', 'complain', 'againts', 'driversbut', 'worry', 'take', 'actionlol']
# 662
#
# ['user', 'review']
# 663
#
# ['poor', 'chap', 'rat', '365', 'idk', 'go', 'wrong', 'smooth', 'polite', 'give', '4', 'star', 'quite', 'old', '96', 'sprinter', 'clean', 'cool', 'ac', 'well']
# 665
#
# ['bd', 'er', 'office', 'e', 'contact', 'korar', 'kono', 'way', 'ase', 'phone', 'number', 'active', 'email']
# 674
#
# ['want', 'know', 'complain', 'driverplus', 'help']
# 677
#
# ['service', 'quite', 'good', '😊', 'unfortunately', 'sometimes', 'creats', 'problems', 'indecent', 'unexpected', 'attitude', 'passengers']
# 682
#
# ['didnt', 'even', 'open', 'account', 'number', 'say', 'already', 'use', 'mean', 'btw', 'give', 'number', 'suppose', 'ask', 'password', 'right']
# 684
#
# ['anyone', 'give', 'invitation', 'free', 'rid', 'thnx', 'advance']
# 686
#
# ['anyone', 'suzuki', 'swift', 'toyota', 'passo', 'rid', 'rat']
# 689
#
# ['anyone', 'share', 'promo', 'code']
# 690
#
# ['want', 'use', 'today', 'first', 'one', 'pls', 'suggest', 'promo', 'code']
# 692
#
# ['refuse', 'banani', 'want', 'mirpur', 'nd', 'cancel', 'either']
# 693
#
# ['post', 'screenshot', 'profile', 'share', 'experience']
# 696
#
# ['assalamualaikum', 'want', 'know', 'cash', 'amount', 'remain', 'stick', 'traffic', 'raise', 'ie', 'request', 'show', '150tk', 'traffic', '1', 'hour', 'meanwhile', 'route', 'reach', 'would', 'amount', 'higher', 'remain', 'reach', 'new', 'know', 'thank']
# 698
#
# ['anyone', 'share', 'promo', 'code']
# 699
#
# ['ki', 'know', 'silly', 'question', 'main', 'fact', 'dont', 'know', 'anything', 'exept', 'mentuoned', '4', 'letter']
# 703
#
# ['get', 'service', 'bill', 'without', 'service', 'come', 'pickup', 'start', 'bill', '50', '10', 'trip', 'max', 'discount', 'tk', '100', 'per', 'valid', '6am3pm', 'till', 'june', '17', '2017', 'map', 'logo', 'tk', '3000', 'thank', 'choose', 'maksudul', 'june', '16', '2017', 'uberx', '0233pm', '100', 'kazi', 'nazrul', 'islam', 'ave', 'dhaka', '1215', 'bangladesh', '0235pm', 'kazi', 'nazrul', 'islam', 'ave', 'dhaka', '1215', 'bangladesh', 'picture', 'md', 'ali', 'ride', 'md', 'ali', '048', 'kilometers', '000200', 'uberx', 'one', 'star', 'two', 'star', 'three', 'star', 'four', 'star', 'five', 'star', 'include', 'fee', 'may', 'charge', 'bank', 'please', 'contact', 'bank', 'directly', 'inquiries', 'base', '5000', 'distance', '1000', '600', 'subtotal', 'tk', '6600', 'round', '300', 'promotion', '3300', 'collect', 'tk', '3000', 'cash', 'visit', 'page', 'information', 'include', 'invoice', 'available', 'xidd989b5fa16994459946f298cf4b5e0dd', 'pgvli2anubxffyeogxta1rmv082993', 'invite', 'friends', 'family', 'give', 'friends', 'free', 'credit', 'try', 'youll', 'bdt100', 'next', '3', 'rid', 'start', 'rid', 'share', 'code', 'maksuduli2ue', 'logo', 'share', 'facebook', 'share', 'twitter', 'share', 'email', 'need', 'help', 'tap', 'help', 'app', 'contact', 'us', 'question', 'leave', 'something', 'behind', 'track']
# 705
#
# ['ekjon', 'jodi', 'dosh', 'kore', 'tahole', 'entire', 'blame', 'ke', 'deyar', 'mane', 'ki', 'sister', 'take', 'least', '50', 'rid', 'far', 'didnt', 'face', 'single', 'unpleasant', 'act', 'feel', 'entire', 'kharap', 'thing', 'plot']
# 710
#
# ['help', 'post', 'body', 'say', 'use', 'promo', 'code']
# 714
#
# ['●', 'u', 'cancel', '5', 'request', 'u', 'block', '56', 'hours']
# 715
#
# ['well', 'happy', 'customer', 'care', 'service']
# 721
#
# ['dear', 'really', 'dont', 'like', 'limit', 'discount', 'either', 'give', 'please', 'give', '6am', '3pm', 'limit', 'thank', 'u']
# 724
#
# ['pay', 'home', 'call', 'midnight', 'sleep', 'could', 'receive', 'morning', '7', 'call', 'think', 'might', 'miss', 'something', 'thats', 'callingi', 'receive', 'receive', 'instantly', 'claim', 'cash', 'give', 'yesterday', 'tear', 'middle', 'note', 'oo', 'impossible', 'give', 'saw', 'clearly', 'question', 'find', 'note', 'problem', 'claim', 'day', 'midnight', 'day', 'claim', 'thread', 'know', 'house', 'address', 'may', 'show', 'passengers', 'ride', 'dn', 'call', 'claim', 'money', 'issue', 'yesterday', 'come', 'home', 'felt', 'something', 'tricky', 'behaviour', 'later', 'wise', 'think', 'maybe', 'general', 'today', 'morning', 'come', 'way', 'stun', 'anyone', 'face', 'issue', 'rule', 'claim', 'money', 'issue', 'pay', 'mainly', 'next', 'day', 'payment']
# 734
#
# ['okay', 'open', 'mouth', 'yesterday', 'fake', 'id', 'name', 'jahangir', 'alam', 'post', 'status', 'group', 'try', 'explain', 'real', 'story', 'behind', 'shanta', 'ghosh', 'controversy', 'post', 'make', 'everyone', 'confuse', 'bring', 'twist', 'situation', 'idk', 'whether', 'true', 'make', 'everyone', 'really', 'confuse', 'mea', 'member', 'group', 'regular', 'passenger', 'also', 'curious', 'like', 'everyone', 'know', 'real', 'story', 'moment', 'confusion', 'increase', 'victim', 'silent', 'let', 'situation', 'worse', 'shanta', 'ghosh', 'mention', 'ger', 'post', 'make', 'record', 'whole', 'situation', 'day', 'could', 'post', 'video', 'audio', 'whatever', 'guess', 'everything', 'would', 'become', 'clear', 'couldve', 'punish', 'deeds', 'comment', 'box', 'ask', 'post', 'record', 'curious', 'like', 'everyone', 'know', 'real', 'story', 'see', 'reply', 'start', 'give', 'threats', 'like', 'wtf', 'also', 'say', 'didnt', 'ask', 'justice', 'something', 'like', 'question', 'doesnt', 'want', 'justice', 'driverr', 'punish', 'shes', 'let', 'situation', 'worse', 'another', 'thing', 'im', 'support', 'anyone', 'case', 'like', 'everyone', 'also', 'want', 'know', 'real', 'story', 'controversy', 'stop', 'give', 'threat', 'wow', 'know', 'whos', 'give', 'much', 'power', 'shes', 'openly', 'give', 'threats', 'others', 'social', 'media', 'guess', 'high', 'stand', 'together', 'matter', 'guy', 'let', 'see', 'beat', 'unity', 'us', 'stand', 'together']
# 735
#
# ['max', 'discount', 'upto', '100', 'per', 'lamest', 'offer', 'offer', '6070', 'discount', 'exceed', '100', 'tk', '😂']
# 739
#
# ['sms', '50', 'discount', 'whereas', 'maximum', 'discount', 'amount', 'upto', '100', 'taka', 'declaration', 'make', 'conflict', 'percentage', 'discount', 'vs', 'value', 'discount', 'basically', 'apply', '50', 'discount', 'maximum', '200', 'taka', '200', 'taka', '50', 'allow', 'calculate', 'maximum', '100', 'taka', 'discount', 'many', 'users', 'avail', 'exactly', '50', 'discount', 'ratio', 'law', 'maximum', 'users', '200', 'taka', 'get', '50', 'discount', 'key', 'announcement', '50', 'actually', '100', 'taka', 'discounttwo', 'type', 'methodology', 'use', 'one', 'promorional', 'communication', 'would', 'one', 'pls', 'share', 'communication', 'comply', 'govt', 'law']
# 743
#
# ['didnt', 'wait', 'behavior', 'polite', 'chitchat', 'even', 'drivers', 'give', '1', 'one', 'payment', 'make', 'via', 'card', 'another', 'cash', 'stop']
# 745
#
# ['possible', 'prebook', 'tomorrow', 'specific', 'vehicle', 'type', 'seat', 'capacity', 'options', 'travel', 'group', '8', 'tia']
# 747
#
# ['upfront', 'fair', '270', 'tk', 'skip', 'destination', '155', 'tk', 'always', 'better', 'use', 'skip', 'destination', 'trick', 'choose', 'shortcut', 'route', 'unless', 'theres', 'huge', 'traffic', 'common', 'even', 'use', 'upfront', 'charge', 'due', 'technical', 'problems', 'maybe', 'intentionally', 'good', 'fraudulent', 'activities', 'world']
# 748
#
# ['hello', 'everyone', 'wish', 'well', 'common', 'problems', 'face', 'everyday', 'please', 'comment', 'post']
# 758
#
# ['hello', 'people', 'need', 'information', 'name', 'mostofa', 'drive', 'black', 'colour', 'fielder', 'one', 'use', 'service', 'please', 'buzz', 'kind', 'urgent']
# 762
#
# ['anyone', 'tell', 'isnt', 'work', 'new', 'dohs']
# 764
#
# ['would', 'love', 'see', 'grab', 'come', 'bangladesh', 'run', 'money']
# 766
#
# ['always', 'another', 'side', 'story', 'accord', 'passenger', 'constantly', 'kick', 'seat', 'back', 'threaten', 'call', 'name', 'ask', 'reply', 'ভাড়া', 'তোর', 'গো', 'ভিতরে', 'ভরমু', 'think', 'point', 'anyone', 'wouldve', 'lose', 'temper', 'refuse', 'take', 'want', 'drop', 'passenger', 'location', 'deny', 'anything', 'put', 'hand', 'passenger', 'definitely', 'punishable', 'crime', 'read', 'post', 'last', 'night', 'believe', 'instantly', 'later', 'think', 'cause', 'woman', 'complain', 'shouldnt', 'believe', 'straight', 'away', 'also', 'try', 'know', 'drivers', 'side', 'story', 'call', 'ask', 'record', 'like', 'hes', 'regular', 'professional', 'hes', 'teacher', 'drive', 'speak', 'surprisingly', 'decently', 'doesnt', 'make', 'saint', 'either', 'listen', 'say', 'genuinely', 'confuse', 'story', 'believe', 'saw', 'passengers', 'comment', 'tell', 'us', 'contact', 'bring', 'users', 'group', 'honestly', 'opinion', 'shady', 'technically', 'hes', 'user', 'way', 'doesnt', 'matter', 'hes', 'use', 'official', 'drivers', 'app', 'im', 'expect', 'hateful', 'reply', 'thank']
# 767
#
# ['call', 'half', 'hour', 'later', 'say', 'make', 'kind', 'technical', 'mistake', 'correct', '300', 'taka', 'ask', 'additional', 'gently', 'suggestions']
# 781
#
# ['need', 'educate', 'payment', '20', 'share', 'profit', 'polite', 'smart', 'challenge', 'drive', '01670900858']
# 786
#
# ['use', '1st', 'yesterdayfor', '2', 'timesit', 'really', 'good', 'drivers', 'good', 'nd', 'also', 'thnx']
# 787
#
# ['happiness', 'get', 'money', 'back']
# 813
#
# ['suggest', 'share', 'code', 'near', 'dear', 'ones', 'track', 'also', 'talk', 'understand', 'track', '3rd', 'party', 'avert', 'impend', 'danger']
# 815
#
# ['observation', 'seem', 'pattern', 'grow', 'drivers', 'start', 'use', 'slang', 'soon', 'riders', 'refuse', 'cancel', 'may', 'find', 'usefully', 'strategy', 'make', 'rider', 'uneasy', 'cancel', 'behavior', 'get', 'viral', 'among', 'drivers', 'may', 'use', 'tool', 'cz', 'officials', 'ignore', 'slang', 'use', 'technic', 'spread']
# 818
#
# ['almost', '50', 'rid', 'highly', 'satisfy', 'service', 'expect', 'better', 'service', 'upcoming', 'dayshope', 'already', 'work', 'satisfy', 'need', 'demand', 'rock', 'uber👌']
# 825
#
# ['see', 'rat', 'one', 'help']
# 827
#
# ['use', 'almost', '5', 'months', 'experience', 'fabulous', 'anyone', 'ask', 'view', 'say', 'bless']
# 830
#
# ['travel', 'farmgate', 'shewrapa', 'upfront', 'show', '100', 'tk', 'promo', 'app', 'show', '475', 'tk', 'promo', 'show', 'travel', '17', 'kilometres', 'actual', 'distance', 'around', '35', 'kilo']
# 831
#
# ['karo', 'kache', 'promo', 'code', 'hobe']
# 832
#
# ['promo', 'cod', 'availableim', 'dire', 'need']
# 837
#
# ['anybody', 'please', 'suggest', 'mean', 'change']
# 838
#
# ['truely', 'ubar', 'problem', 'bite', 'excellent', 'service', 'tremendous', 'grow', 'industry', 'stand', 'behind', 'ubar']
# 859
#
# ['yesterday', 'two', 'drivers', 'receive', 'request', 'overphone', 'deny', 'funny']
# 860
#
# ['may', 'longest', 'bd', '😂😂😂', 'gps', 'blackout']
# 862
#
# ['assalamualaikum', 'would', 'like', 'know', 'whether', 'see', 'pickup', 'location', 'accept', 'request', 'yesterday', 'request', 'accept', 'request', 'minutes', 'call', 'know', 'mention', 'shahabag', 'pickup', 'location', 'dhanmondi', 'ask', 'accept', 'request', 'nearby', 'tell', 'wait', 'place', 'obviously', 'possible', 'within', '5', 'mins', 'shahabag', 'dhanmondi', 'much', 'traffic', 'jam', 'road', 'tell', 'rush', 'need', 'university', 'quickly', 'tell', 'cancel', 'request', 'keep', 'argue', 'drivers', 'see', 'pickup', 'address', 'accept', 'request', 'finally', 'cancel', 'sad', 'see', 'drivercar', 'rat', '47']
# 865
#
# ['watch', 'lot', 'positive', 'comment']
# 869
#
# ...
# 6813
#
# ['247', 'helpline', 'office', 'bangladesh']
# 6816
#
# ['sleep', 'day', 'though']
# 6817
#
# ['option', 'app', 'receive', 'sms', 'number', 'mean', 'wont', 'offer', 'take', 'help', 'plz']
# 6820
#
# ['old', 'user', 'need', 'know', '250', 'tk', 'free']
# 6821
#
# ['wonder', 'anybody', 'share', 'customer', 'care', 'number']
# 6822
#
# ['hotline', 'number', 'contact', 'registration', 'detail']
# 6823
#
# ['cool', '😜😜😜']
# 6825
#
# ['rid']
# 6826
#
# ['two', 'promotionss', 'use', 'first', 'enter', 'bdt', '250', 'first']
# 6827
#
# ['first', 'thank', 'lot', 'amaze', 'service', 'promo', 'code', 'work', 'please', 'kindly', 'let', 'know', 'suppose', 'thank', 'advance']
# 6828
#
# ['hi', 'everyone', 'share', 'first', 'yesterday', 'book', 'uberx', 'around', '627pm', 'uttara', 'sector', '13', 'gulshan', '1', 'call', 'tell', 'pickup', 'location', 'detail', 'felt', 'like', 'bad', 'navigation', 'book', 'show', '05min', 'distance', 'arrive', 'around', '12mins', 'later', 'also', 'problem', 'device', 'reach', 'destination', 'charge', 'bdt485', 'first', 'promo', 'code', 'work', 'also', 'later', 'check', 'previous', 'show', 'book', '627pm', 'uberx', 'pick', '638pm', 'mean', 'intentionally', 'press', 'pick', 'button', 'end', 'charge', 'extra', 'also', 'first', 'promo', 'code', 'work', 'welcome', 'bangladesh', 'long', 'way', 'worry', 'nature', 'keep', 'good', 'things', 'good', 'enjoy', 'everyone', 'aware']
# 6829
#
# ['give', 'user', 'otp', 'like', 'use', 'ola', 'drivers', 'cant', 'start', 'journey', 'customer', 'get', 'say', 'guy']
# 6830
#
# ['home', 'tgis', 'say', 'trio', 'refuse', 'cancel', 'thats', 'please', 'helo', 'complain']
# 6834
#
# ['appits', 'saidif', 'use', 'promogift', 'code', 'friendi', 'bonus', 'amount', 'tk', '250butevery', 'put', 'codethe', 'reply', 'belowi', 'didnt', 'single', 'discount', 'use', 'others', 'codehow', 'tia']
# 6835
#
# ['share', 'promo', 'friendthen', 'get', 'free', 'rideby', 'rule', 'friends', 'get', 'free', 'ridethen', 'use', 'till', 'friend', 'didnt', 'promotionis', 'stop', 'nb', 'last', 'didnt', 'turn', 'network', 'connection']
# 6836
#
# ['pay', 'use', 'credit', 'card', 'international', 'one']
# 6838
#
# ['cancel', 'due', 'miss', 'call', 'pay', 'anything']
# 6839
#
# ['register']
# 6842
#
# ['next', 'year', 'want', 'celebrate', 'day', 'seek', 'keen', 'support', 'authority']
# 6848
#
# ['respond']
# 6849
#
# ['take', 'yesterday', 'pay', '500', 'tk', 'return', '100', 'tk', 'less', 'complain', 'help']
# 6850
#
# ['around', '10', 'pm', 'everyday', 'drivers', 'give', 'excuse', 'ask', 'kolabagan', 'towards', 'mirpur', 'strange', 'like', 'use', 'cng', 'wherein', 'mood', 'main', 'factor', 'convenience', 'customer', 'dont', 'see', 'point', 'available', '24', 'hours', 'dhaka', 'also', 'apart', 'use', 'airconditioning', 'seat', 'arrangement']
# 6854
#
# ['would', 'httpswwwfacebookcom168310283531918videos346395442390067']
# 6858
#
# ['anyone', 'whos', 'assign', 'need', 'advice']
# 6860
#
# ['idea', 'customization', 'destination', 'im', 'new', 'actually', 'confirm', 'exact', 'location', 'confirm', 'nearby', 'location', 'map', 'one', 'thing', 'route', 'customize', 'way']
# 6861
#
# ['request', 'call', 'far', 'hence', 'cancel', 'however', 'even', 'though', 'press', 'cancel', 'apparently', 'didnt', 'cancel', 'didnt', 'cancellation', 'fee', 'either', 'home', 'bus', 'receipt', 'dont', 'understand', 'happen', 'usually', 'pay', 'cash', 'im', 'worry', 'money', 'take', 'claim', 'owe', 'problem', 'later', 'anyone', 'experience', 'take', 'step', 'alright']
# 6863
#
# ['add', 'promo', 'code', 'moniri23ue', '250tk', 'first']
# 6866
#
# ['read', 'bangladesh']
# 6868
#
# ['face', 'map', 'problem', 'today', 'first', 'mohammadpur', 'say', 'elephant', 'road', 'though', 'map', 'show', 'nearby', 'cancel', 'think', 'report', 'afterwards', 'call', 'another', 'babar', 'road', 'agree', '5', 'minutes', 'saw', 'move', 'come', 'pickup', 'point', 'call', 'say', '2', 'mins', 'away', 'mins', 'get', 'map', 'still', 'show', 'freeze', 'far', 'away', 'later', 'realize', 'really', 'map', 'issue', 'felt', 'share', 'tnks']
# 6870
#
# ['nobonita', 'give', 'free', 'bdt250', 'claim', 'free', 'gift', 'sign', 'use', 'link']
# 6872
#
# ['use', 'today', 'first', 'happy', 'service', 'use', 'promo', 'code', 'luinkue', '250', 'taka']
# 6873
#
# ['promo', 'code', 'available', '25', '10am', '3pm', '100', 'tk', 'discount', 'idea', 'one', 'consider', 'first', 'p']
# 6874
#
# ['wish', 'p']
# 6877
#
# ['use', 'code', 'free', 'wasifk431ue']
# 6882
#
# ['exact', 'office', 'location', 'uttara', 'contact', 'number', 'please', 'help']
# 6883
#
# ['1st', 'ki', '150', 'expert', 'opinion', 'plz']
# 6884
#
# ['customer', 'care', 'number', 'bangladesh', 'choose', 'credit', 'card', 'payment', 'mu', 'drop', 'go', 'away', 'cant', 'pay', 'credit', 'card', 'due', 'dificulties']
# 6886
#
# ['menu', 'promotions', 'add', 'code', 'moniri23ue', '250', 'bdt', 'free']
# 6889
#
# ['new', 'users', 'use', 'code', 'qafisue', 'tk', '250', 'discount', 'free', 'apps', 'menu', 'payment', 'choose', 'add', 'promo', 'gift', 'code', 'enter', 'code', 'simply', 'take', 'automatically', 'discount']
# 6891
#
# ['promo', 'code', 'ki', 'vabe', 'use', 'korbo', 'ami', 'kokhono', 'promo', 'code', 'use', 'kori', 'ni', 'pls', 'help', 'discount', 'use', 'pay', 'exclude', 'promo', 'code', 'need', 'quick', 'response', 'help', 'need', '15', 'mins', 'thank']
# 6894
#
# ['nobonita', 'give', 'free', 'bdt250', 'claim', 'free', 'gift', 'sign', 'use', 'link']
# 6898
#
# ['good', 'job', 'im', 'happy']
# 6899
#
# ['happy', 'first', 'pleasant']
# 6902
#
# ['khandaker', 'give', 'free', 'bdt250', 'claim', 'free', 'gift', 'sign', 'use', 'link']
# 6905
#
# ['hi', 'kamalapur', 'railway', 'station', 'dhanmondi', '3', 'people', 'theyll', 'charge', 'per', 'person', 'right', 'allow', 'luggage']
# 6907
#
# ['hotline', 'number']
# 6908
#
# ['rate', 'government', 'know', 'cheap', '😂😂😂']
# 6910
#
# ['want', 'join', 'register', 'im', 'sure', 'security', 'passengers', 'mug', 'st', 'hijack']
# 6913
#
# ['come', 'hike', '😕']
# 6915
#
# ['bad', 'news', 'high', 'jam', 'city', 'reduce', 'least']
# 6916
#
# ['anyone', 'confirm', 'whether', 'take', '4', 'passengers', 'rid', 'example', '4', 'passengers', '4', 'kid']
# 6917
#
# ['operate', '2', 'months', '2022', 'hike', 'without', 'fuel', 'price', 'hike', 'country', 'might', 'accept', 'positive', 'way', 'among', 'users', 'bangladesh', 'still', 'lot', 'acquaint', 'clients', 'hope', 'new', 'effective', 'business', 'ideas', 'benefit', 'stakeholders']
# 6918
#
# ['could', 'free', 'use', 'another', 'new', 'email🚗']
# 6919
#
# ['way', 'change', 'mobile', 'number', 'someone', 'intially', 'register', 'case', 'lose', 'previous', 'one', 'longer', 'use', 'edit', 'option', 'didnt', 'find', 'edit', 'option']
# 6922
#
# ['enjoy', '1st', 'use', 'promo', 'code', 'free', 'nahidh378ue']
# 6923
#
# []
# 6924
#
# ['75p61', 'use', 'promo', 'code', 'free', 'upto', '250', 'tk', 'cheeers', '😎']
# 6925
#
# ['first', 'ensure', 'optimum', 'availability', 'thats', 'frustrate', 'get', 'one', 'need']
# 6926
#
# ['mda52401ue', 'use', 'promo', 'card', 'u', '250tk']
# 6927
#
# ['faisalm4245ue', 'use', 'promo', 'code', 'use', 'turn']
# 6928
#
# ['free', 'bdt250', 'claim', 'free', 'gift', 'sign', 'use', 'link']
# 6929
#
# ['hlw', 'good', 'people', 'plz', 'let', 'know', 'use', 'whenever', 'open', 'apps', 'map', 'show', 'proceed']
# 6930
#
# ['mushfiquer', 'give', 'free', 'bdt250', 'claim', 'free', 'gift', 'sign', 'use', 'link', 'httpswwwubercominvitemushfiquerrue']
# 6931
#
# ['proma', 'give', 'free', 'bdt250', 'claim', 'free', 'gift', 'sign', 'use', 'link']
# 6932
#
# ['hi', 'issue', 'payment', 'pay', 'cash', 'app', 'try', 'make', 'transaction', 'credit', 'card', 'set', 'put', 'credit', 'card', 'info', 'amount', 'still', 'pending', 'although', 'pay', 'cash', 'order', 'another', 'payment', 'resolve', 'solution', 'center', 'number']
# 6934
#
# ['today', 'get', 'problem', 'regard', 'coupon', 'mother', 'old', 'type', 'phone', 'register', 'number', 'mobile', 'mobile', 'log', 'mother', 'account', 'try', 'request', 'service', 'notification', 'show', 'promotion', 'work', 'bill', 'full', 'referral', 'coupon', 'go', 'didnt', 'understand', 'happen', 'account', 'referral', 'coupon', 'account', 'anyone', 'experience', 'know', 'hiw', 'resolve']
# 6935
#
# ['amaze', 'experience', 'far', 'best', 'service', 'provider', 'bangladesh', 'till', 'thank', 'million', 'shireen', 'apu', 'n', 'aumi', 'bhai', 'help', 'n', 'direct', 'great', 'petience']
# 6936
#
# ['noor', 'give', 'free', 'bdt250', 'claim', 'free', 'gift', 'sign', 'use', 'link']
# 6937
#
# ['hop', 'see', 'female', 'drivers', 'soon', 'think', 'would', 'great', 'see', 'cars', 'drive', 'women']
# 6938
#
# ['job', 'circular', 'call', 'applicants', 'bangladesh', 'look', 'candidates', 'operations', 'department', 'think', 'know', 'excel', 'good', 'people', 'management', 'take', 'pressure', 'cope', 'situation', 'apply', 'salary', 'minimum', '15k', '6', 'days', 'week', '10', '6', 'pm', 'location', 'uttara', '12', 'apply', 'send', 'cv', 'mhaqueextubercom', 'explanation', 'well', 'suit', 'base', 'criteria', 'subject', 'applicants', 'source', 'vacancy', 'announcement']
# 6939
#
# ['hi', 'use', 'ubar', '25112016', '2141', 'hrs', '154', 'taka', 'use', 'first', '200', 'taka', 'free', 'also', 'say', 'dont', 'need', 'give', 'money', 'yesterday', 'want', 'use', 'ubar', 'say', 'get', '154', 'taka', 'possible']
# 6940
#
# ['never', 'late', 'grab', 'free', 'enjoy']
# 6942
#
# ['dont', 'hesitate', 'flag', 'kind', 'issue', 'regard', 'payments', 'drivers', 'whatever', 'take', 'customeruser', 'feedback', 'seriously', 'replyresolves', 'within', '24', 'hours', 'stupid', 'rat', '39', 'start', 'atleast', '20', 'mins', 'get', 'claim', 'didnt', 'automatically', 'turn', 'post', 'issue', 'adjust', 'bill', 'give', '75', 'bdt', 'credit']
# 6943
#
# ['dont', 'hesitate', 'flag', 'kind', 'issue', 'regard', 'payments', 'drivers', 'whatever', 'take', 'customeruser', 'feedback', 'seriously', 'replyresolves', 'within', '24', 'hours', 'stupid', 'rat', '39', 'start', 'atleast', '20', 'mins', 'get', 'claim', 'didnt', 'automatically', 'turn', 'post', 'issue', 'adjust', 'bill', 'give', '75', 'bdt', 'credit']
# 6944
#
# ['complain', 'reckless', 'drive', 'cross', 'tejgaon', 'rail', 'cross', 'wrong', 'side', 'though', 'say', 'ever', 'face', 'issue', 'whether', 'deny', 'somewhere', 'bad', 'attitude', 'bad', 'service', 'history', 'select', 'ridedriver', 'need', 'help', 'report', 'issue', 'list', 'options']
# 6946
#
# ['smartest', 'u', 'could', 'use', 'wana', 'free', 'try', 'code', 'nahidh378ue']
# 6947
#
# ['gulshan1', 'mirpur2', 'first', 'tym', 'go']
# 6948
#
# ['exactly', 'use', 'promo']
# 6950
#
# ['happen', 'december', '20th', 'take', 'mirpur', 'mohakhali', 'surprisingly', 'didnt', 'charge', 'anything', 'distance', 'surprise', 'think', 'problem', 'apps']
# 6952
#
# ['1', 'free', 'use', 'mdr14982ue']
# 6953
#
# ['anyone', 'say', 'objection', 'certificate', 'apps']
# 6954
#
# ['feedback', 'drivers', '47', 'rat', 'allion', 'cars', 'best', 'avoid', 'probox', 'worst', 'nice', 'day', 'use']
# 6955
#
# ['helppost', 'hello', 'everyone', 'download', 'app', 'play', 'store', 'try', 'create', 'account', 'couldnt', 'itafter', 'give', 'password', 'say', 'incorrect', 'password', 'forget', 'passwordit', 'say', 'email', 'associate', 'number', 'try', '67', 'time', 'different', 'email', 'address', 'alsowhat']
# 6956
#
# ['use', 'almost', 'everyday', 'really', 'satisfy', 'service', 'behaviour', 'drivers', 'today', 'request', 'mohakhali', 'dohs', 'mirpur', 'get', 'guy', 'call', 'kochukhet', 'ask', 'location', 'want', 'say', 'mirpur', 'like', 'amar', 'mirpur', 'gele', 'taka', 'poshabe', 'na', 'hurry', 'know', 'new', 'rule', 'cancel', '5', 'minutes', 'gon', 'na', 'charge', 'thats', 'didnt', 'argue', 'mr', 'mehadi', 'really', 'today', 'disappoint', 'sorry', 'long', 'post', '🚗']
# 6958
#
# ['utshar11ue', 'please', 'use', 'code', 'free']
# 6960
#
# ['take', 'first', '2nd', 'wed', 'today', 'first', 'one', 'simply', 'awesome', 'get', 'brand', 'new', 'premieo', 'wood', 'interior', 'chilzzz', 'cool', 'parent', 'skeptic', 'even', 'amaze', '350bdt', '100', 'bdt', 'use', 'promo', 'code', 'mirpur', '1', 'ahmednagar', 'officer', 'club', '2nd', 'backmeh', 'much', 'probox', 'shaky', 'issue', 'brake', 'guess', 'annoy', 'traffic', 'kaoran', 'bazar', 'kalyanpur', 'total', '400', 'bdt', 'definitely', 'use', 'cng', 'office', 'dohsbanani', 'home', 'mirpur', 'definitely', 'use', 'via', 'cantonment']
# 6963
#
# ['last', 'night', 'payment', 'option', 'credit', 'card', 'drop', 'destination', 'tell', 'card', 'charge', 'right', 'continue', 'sms', 'insufficient', 'balance', 'card', 'result', 'could', 'charge', 'call', 'bank', 'get', 'know', 'try', 'charge', 'card', 'usd', 'portion', 'enable', 'usd', 'option', 'pay', 'amount', 'write', 'inform', 'group', 'members', 'someone', 'put', 'hisher', 'card', 'payment', 'method', 'would', 'charge', 'usd', 'bdt', 'option']
# 6964
#
# ['enjoy', '1st', 'use', 'promo', 'code', 'free', 'fardinm43ue']
# 6966
#
# ['reserve', 'use', 'thank', 'advance']
# 6967
#
# ['promo', 'code', 'im', 'save', 'promo', 'cod']
# 6969
#
# ['add', 'card', 'payment', 'method', 'look', 'suggestions', 'fail', 'verify', 'payment', 'last', 'select', 'card', 'payment', 'method', 'payment', 'unsuccessful', 'cant', 'request', 'ask', 'pay', 'pending', 'payment', 'new']
# 6970
#
# ['ny', 'promo', 'code', 'fardinm43ue', 'use', 'code', 'free', 'enjoy', '😊😉']
# 6971
#
# ['promo', 'code', 'pls', 'free', 'rid', 'tia', '😊']
# 6973
#
# ['take', '2nd', 'bashundhara', 'mirpur', 'dohs', 'iskander', 'toyota', 'allion', 'ga19', 'clean', 'well', 'behave', 'need', 'help', 'directions', 'problem', 'get', '40', 'use', 'friday', 'promo', 'code', 'great', 'service', 'hope', 'stay', 'bd']
# 6974
#
# ['comment', 'promotion', 'code', 'code', 'fayaazb4ue']
# 6975
#
# ['use', 'last', 'night', 'travel', 'banani', 'mirpur', 'dohs', 'fantastic', 'service', 'hassle', 'safe', 'well', 'behave', 'comfortable', 'tk', '250', 'consider', 'fact', 'get', 'pick', 'didnt', 'stand', 'road', 'night', 'travel', 'ac', 'would', 'say', 'much', 'cheaper', 'cng', 'inshaallah', 'brta', 'wont', 'stop']
# 6978
#
# ['anyone', 'tell', 'whats', 'procedure', 'call', 'cab']
# 6979
#
# ['great', 'experience', '😂😂', 'reach', 'safely', 'alhamdulillah']
# 6982
#
# ['go', 'close', 'operation', 'bangladesh', 'hope', 'answer', 'noalso', 'solve', 'problem', 'quickly', 'bestservice']
# 6983
#
# ['hello', 'everyone', 'guess', 'know', 'notice', 'regard', 'ban', 'unofficial', 'group', 'notice', 'group', 'activities', 'hope', 'sort', 'matter', 'soon', 'possible', 'thank']
# 6984
#
# ['android', 'app', 'install']
# 6985
#
# ['try', '30', 'mins', 'p', 'nearest', 'one', 'karwan', 'bazar', 'p']
# 6986
#
# ['try', 'two', 'time', 'today', 'service', 'good', 'yeah', 'ladies', 'think', 'much', 'safe']
# 6987
#
# ['head', 'office', 'locate', 'bd']
# 6988
#
# ['experience', 'today', 'overall', 'service', 'satisfy']
# 6989
#
# ['available', 'dhanmondi', 'morning']
# 6990
#
# ['really', 'wish', 'guy', 'bestall', 'success', 'inshaallahhope', 'work', 'us', 'transportation', 'problems', 'timesim', 'really', 'happymashaallah']
# 6992
#
# []
# 6993
#
# ['well', 'first', 'experience', 'pretty', 'good', 'try', 'one', 'mohakhali', 'dohs', 'aftabnagar', 'free', 'turn', 'good', 'one', 'later', 'try', 'one', 'back', 'home', 'aftabnagar', 'rampura', '’', 'find', 'nearby', 'app', 'give', '45', 'drivers', 'accord', 'app', '9', 'mins', 'away', 'mostly', 'around', 'gulshan', 'mohakhali', 'area', 'pretty', 'much', 'obvious', 'consider', 'traffic', '’', 'really', 'hopeful', 'service', 'look', 'forward']
# 6994
#
# ['well', 'know', 'start', 'operation', 'bangladesh', 'recently', 'group', 'work', 'platform', 'users', 'bangladesh', 'share', 'experience', 'query', 'regard', 'unofficial', 'group', 'people', 'share', 'experience', 'regard', 'irrelevant', 'post', 'delete', 'responsible', 'person', 'remove']
# 6995
#
# ['anyone', 'know', 'representative', 'please', 'let', 'knowhave', 'lot', 'constructive', 'feedback', 'good', 'initiative', 'feel', 'leap', 'bound', 'cover']
# 6996
#
# ['first', 'experience', 'dhaka', 'really', 'satisfactory']
# 6997
#
# ['well', 'know', 'start', 'operation', 'bangladesh', 'recently', 'group', 'work', 'platform', 'users', 'bangladesh', 'share', 'experience', 'query', 'regard']
# count: 6997

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True
